# %%
import pandas as pd
import numpy as np

# %%
group_1 = pd.read_csv('group_1_edge.txt', sep = " ")
group_2 = pd.read_csv('group_2_edge.txt', sep = " ")
group_3 = pd.read_csv('group_3_edge.txt', sep = " ")
group_4 = pd.read_csv('group_4_edge.txt', sep = " ")
group_5 = pd.read_csv('group_5_edge.txt', sep = " ")

# %%
group_1_1 = np.array(group_1[group_1.Company == 1][['Business']])
group_1_1 = group_1_1.reshape(1,len(group_1_1))

# %%
group_1_1 = np.array(group_1[group_1.Company == 1][['Business']])
group_1_1 = group_1_1.reshape(1,len(group_1_1))

group_1_2 = np.array(group_1[group_1.Company == 2][['Business']])
group_1_2 = group_1_2.reshape(1,len(group_1_2))

group_1_3 = np.array(group_1[group_1.Company == 3][['Business']])
group_1_3 = group_1_3.reshape(1,len(group_1_3))

group_1_4 = np.array(group_1[group_1.Company == 4][['Business']])
group_1_4 = group_1_4.reshape(1,len(group_1_4))

group_1_5 = np.array(group_1[group_1.Company == 5][['Business']])
group_1_5 = group_1_5.reshape(1,len(group_1_5))

group_1_6 = np.array(group_1[group_1.Company == 6][['Business']])
group_1_6 = group_1_6.reshape(1,len(group_1_6))

group_1_7 = np.array(group_1[group_1.Company == 7][['Business']])
group_1_7 = group_1_7.reshape(1,len(group_1_7))

group_1 = pd.concat([pd.DataFrame(group_1_1), pd.DataFrame(group_1_2), pd.DataFrame(group_1_3),
          pd.DataFrame(group_1_4),pd.DataFrame(group_1_5),pd.DataFrame(group_1_6),
          pd.DataFrame(group_1_7)])

group_1.set_index(np.arange(1,8), inplace = True)

group_1.fillna(0,inplace = True)
group_1 = group_1.astype('int64')

# %%
group_2_1 = np.array(group_2[group_2.Company == 1][['Business']])
group_2_1 = group_2_1.reshape(1,len(group_2_1))

group_2_2 = np.array(group_2[group_2.Company == 2][['Business']])
group_2_2 = group_2_2.reshape(1,len(group_2_2))

group_2_3 = np.array(group_2[group_2.Company == 3][['Business']])
group_2_3 = group_2_3.reshape(1,len(group_2_3))

group_2_4 = np.array(group_2[group_2.Company == 4][['Business']])
group_2_4 = group_2_4.reshape(1,len(group_2_4))

group_2_5 = np.array(group_2[group_2.Company == 5][['Business']])
group_2_5 = group_2_5.reshape(1,len(group_2_5))

group_2_6 = np.array(group_2[group_2.Company == 6][['Business']])
group_2_6 = group_2_6.reshape(1,len(group_2_6))

group_2_7 = np.array(group_2[group_2.Company == 7][['Business']])
group_2_7 = group_2_7.reshape(1,len(group_2_7))

group_2 = pd.concat([pd.DataFrame(group_2_1), pd.DataFrame(group_2_2), pd.DataFrame(group_2_3),
          pd.DataFrame(group_2_4),pd.DataFrame(group_2_5),pd.DataFrame(group_2_6),
          pd.DataFrame(group_2_7)])

group_2.set_index(np.arange(1,8), inplace = True)

group_2.fillna(0,inplace = True)
group_2 = group_2.astype('int64')

# %%
group_3_1 = np.array(group_3[group_3.Company == 1][['Business']])
group_3_1 = group_3_1.reshape(1,len(group_3_1))

group_3_2 = np.array(group_3[group_3.Company == 2][['Business']])
group_3_2 = group_3_2.reshape(1,len(group_3_2))

group_3_3 = np.array(group_3[group_3.Company == 3][['Business']])
group_3_3 = group_3_3.reshape(1,len(group_3_3))

group_3_4 = np.array(group_3[group_3.Company == 4][['Business']])
group_3_4 = group_3_4.reshape(1,len(group_3_4))

group_3_5 = np.array(group_3[group_3.Company == 5][['Business']])
group_3_5 = group_3_5.reshape(1,len(group_3_5))

group_3_6 = np.array(group_3[group_3.Company == 6][['Business']])
group_3_6 = group_3_6.reshape(1,len(group_3_6))

group_3_7 = np.array(group_3[group_3.Company == 7][['Business']])
group_3_7 = group_3_7.reshape(1,len(group_3_7))

group_3 = pd.concat([pd.DataFrame(group_3_1), pd.DataFrame(group_3_2), pd.DataFrame(group_3_3),
          pd.DataFrame(group_3_4),pd.DataFrame(group_3_5),pd.DataFrame(group_3_6),
          pd.DataFrame(group_3_7)])

group_3.set_index(np.arange(1,8), inplace = True)

group_3.fillna(0,inplace = True)
group_3 = group_3.astype('int64')

# %%
group_4_1 = np.array(group_4[group_4.Company == 1][['Business']])
group_4_1 = group_4_1.reshape(1,len(group_4_1))

group_4_2 = np.array(group_4[group_4.Company == 2][['Business']])
group_4_2 = group_4_2.reshape(1,len(group_4_2))

group_4_3 = np.array(group_4[group_4.Company == 3][['Business']])
group_4_3 = group_4_3.reshape(1,len(group_4_3))

group_4_4 = np.array(group_4[group_4.Company == 4][['Business']])
group_4_4 = group_4_4.reshape(1,len(group_4_4))

group_4_5 = np.array(group_4[group_4.Company == 5][['Business']])
group_4_5 = group_4_5.reshape(1,len(group_4_5))

group_4_6 = np.array(group_4[group_4.Company == 6][['Business']])
group_4_6 = group_4_6.reshape(1,len(group_4_6))

group_4_7 = np.array(group_4[group_4.Company == 7][['Business']])
group_4_7 = group_4_7.reshape(1,len(group_4_7))

group_4 = pd.concat([pd.DataFrame(group_4_1), pd.DataFrame(group_4_2), pd.DataFrame(group_4_3),
          pd.DataFrame(group_4_4),pd.DataFrame(group_4_5),pd.DataFrame(group_4_6),
          pd.DataFrame(group_4_7)])

group_4.set_index(np.arange(1,8), inplace = True)

group_4.fillna(0,inplace = True)
group_4 = group_4.astype('int64')

# %%
group_5_1 = np.array(group_5[group_5.Company == 1][['Business']])
group_5_1 = group_5_1.reshape(1,len(group_5_1))

group_5_2 = np.array(group_5[group_5.Company == 2][['Business']])
group_5_2 = group_5_2.reshape(1,len(group_5_2))

group_5_3 = np.array(group_5[group_5.Company == 3][['Business']])
group_5_3 = group_5_3.reshape(1,len(group_5_3))

group_5_4 = np.array(group_5[group_5.Company == 4][['Business']])
group_5_4 = group_5_4.reshape(1,len(group_5_4))

group_5_5 = np.array(group_5[group_5.Company == 5][['Business']])
group_5_5 = group_5_5.reshape(1,len(group_5_5))

group_5_6 = np.array(group_5[group_5.Company == 6][['Business']])
group_5_6 = group_5_6.reshape(1,len(group_5_6))

group_5_7 = np.array(group_5[group_5.Company == 7][['Business']])
group_5_7 = group_5_7.reshape(1,len(group_5_7))

group_5 = pd.concat([pd.DataFrame(group_5_1), pd.DataFrame(group_5_2), pd.DataFrame(group_5_3),
          pd.DataFrame(group_5_4),pd.DataFrame(group_5_5),pd.DataFrame(group_5_6),
          pd.DataFrame(group_5_7)])

group_5.set_index(np.arange(1,8), inplace = True)

group_5.fillna(0,inplace = True)
group_5 = group_5.astype('int64')

# %%
group_1.to_csv("group_1_EdgeList.txt", sep = " ", index = True, header = False)
group_2.to_csv("group_2_EdgeList.txt", sep = " ", index = True, header = False)
group_3.to_csv("group_3_EdgeList.txt", sep = " ", index = True, header = False)
group_4.to_csv("group_4_EdgeList.txt", sep = " ", index = True, header = False)
group_5.to_csv("group_5_EdgeList.txt", sep = " ", index = True, header = False)
